# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Bike_Share_London.csv")

# %%
data
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0     01/01/2016 00:00  786  6.0  3.5  81.0        13.0             1
# 1     01/01/2016 01:00  660  5.5  3.0  84.0        11.0             1
# 2     01/01/2016 02:00  387  5.0  2.5  84.0        10.0             1
# 3     01/01/2016 03:00  294  5.0  4.5  81.0         5.0             1
# 4     01/01/2016 04:00  219  5.0  4.0  76.0         5.5             1
# ...                ...  ...  ...  ...   ...         ...           ...
# 8694  31/12/2016 19:00  493  9.0  6.0  82.0        17.0             4
# 8695  31/12/2016 20:00  465  8.5  6.5  84.5        13.0             4
# 8696  31/12/2016 21:00  474  8.0  6.0  87.0        12.0             4
# 8697  31/12/2016 22:00  587  8.0  6.0  90.0        12.0             4
# 8698  31/12/2016 23:00  697  8.0  5.0  87.0        18.5             4
#
#       is_holiday  is_weekend  season
# 0              1           0       3
# 1              1           0       3
# ...

# %%
data.columns = ['Time Stamp', 'Count', 'Temperature', 'F_temp', 'Humidity', 'Wind Speed', 'Weather Code', 'Is Hoilday', 'Is Weekend', 'Season']

# %%
data
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 0     01/01/2016 00:00    786          6.0     3.5      81.0        13.0
# 1     01/01/2016 01:00    660          5.5     3.0      84.0        11.0
# 2     01/01/2016 02:00    387          5.0     2.5      84.0        10.0
# 3     01/01/2016 03:00    294          5.0     4.5      81.0         5.0
# 4     01/01/2016 04:00    219          5.0     4.0      76.0         5.5
# ...                ...    ...          ...     ...       ...         ...
# 8694  31/12/2016 19:00    493          9.0     6.0      82.0        17.0
# 8695  31/12/2016 20:00    465          8.5     6.5      84.5        13.0
# 8696  31/12/2016 21:00    474          8.0     6.0      87.0        12.0
# 8697  31/12/2016 22:00    587          8.0     6.0      90.0        12.0
# 8698  31/12/2016 23:00    697          8.0     5.0      87.0        18.5
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# ...

# %%
len(data)
# Out:
# 8699

# %%
data.count()
# Out:
# Time Stamp      8699
# Count           8699
# Temperature     8699
# F_temp          8699
# Humidity        8699
# Wind Speed      8699
# Weather Code    8699
# Is Hoilday      8699
# Is Weekend      8699
# Season          8699
# dtype: int64

# %%
data.head(24)
# Out:
#           Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 0   01/01/2016 00:00    786          6.0     3.5      81.0        13.0
# 1   01/01/2016 01:00    660          5.5     3.0      84.0        11.0
# 2   01/01/2016 02:00    387          5.0     2.5      84.0        10.0
# 3   01/01/2016 03:00    294          5.0     4.5      81.0         5.0
# 4   01/01/2016 04:00    219          5.0     4.0      76.0         5.5
# 5   01/01/2016 05:00    153          4.0     3.5      87.0         5.0
# 6   01/01/2016 06:00    120          3.0     0.0      87.0        10.0
# 7   01/01/2016 07:00     96          3.0     0.0      87.0        12.0
# 8   01/01/2016 08:00    117          3.0     0.0      87.0        12.0
# 9   01/01/2016 09:00    165          4.5     1.5      84.0        14.0
# 10  01/01/2016 10:00    358          5.5     2.5      76.0        17.0
# 11  01/01/2016 11:00    595          6.5     3.5      81.0        16.0
# ...

# %%
data.tail(24)
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 8675  31/12/2016 00:00    146          5.0     2.5     100.0        10.0
# 8676  31/12/2016 01:00    123          5.0     3.5     100.0         7.5
# 8677  31/12/2016 02:00     85          6.0     4.0      93.0         8.0
# 8678  31/12/2016 03:00     49          6.0     3.5      93.0        12.0
# 8679  31/12/2016 04:00     50          6.5     4.5      93.0        11.0
# 8680  31/12/2016 05:00     48          7.0     5.0      93.0        11.0
# 8681  31/12/2016 06:00     51          7.0     5.0      93.0        11.0
# 8682  31/12/2016 07:00     93          7.0     4.5      90.0        15.0
# 8683  31/12/2016 08:00    211          6.0     2.5      96.5        17.5
# 8684  31/12/2016 09:00    376          6.0     3.0     100.0        14.0
# 8685  31/12/2016 10:00    642          7.0     4.0      93.0        15.0
# 8686  31/12/2016 11:00    824          7.0     4.0      93.0        18.0
# ...

# %%
data['Count'].max()
# Out:
# 5422

# %%
data[data["Count"].max() == data['Count']]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 6093  14/09/2016 08:00   5422         22.5    22.5      71.0        14.0
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# 6093             1           0           0       2

# %%
Season_b = data.groupby('Season')

# %%
Season_b

# %%
Season_b.groups
# Out:
# {0: [1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, ...], 1: [3624, 3625, 3626, 3627, 3628, 3629, 3630, 3631, 3632, 3633, 3634, 3635, 3636, 3637, 3638, 3639, 3640, 3641, 3642, 3643, 3644, 3645, 3646, 3647, 3648, 3649, 3650, 3651, 3652, 3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3666, 3667, 3668, 3669, 3670, 3671, 3672, 3673, 3674, 3675, 3676, 3677, 3678, 3679, 3680, 3681, 3682, 3683, 3684, 3685, 3686, 3687,
# ...

# %%
Season_b.get_group(0).mean(numeric_only=True)
# Out:
# Count           1107.348084
# Temperature       10.406706
# F_temp             9.092381
# Humidity          69.882071
# Wind Speed        15.440922
# Weather Code       2.705292
# Is Hoilday         0.043796
# Is Weekend         0.277828
# Season             0.000000
# dtype: float64

# %%
Season_b.get_group(0)["Count"].mean()
# Out:
# 1107.3480839416059

# %%
(Season_b.get_group(0)["Count"].mean())*24
# Out:
# 26576.35401459854

# %%
Season_b.get_group(1)["Count"].mean()
# Out:
# 1480.6582799634034

# %%
(Season_b.get_group(1)["Count"].mean())*24
# Out:
# 35535.79871912168

# %%
Season_b.get_group(2)["Count"].mean()
# Out:
# 1229.9226107226107

# %%
(Season_b.get_group(2)["Count"].mean())*24
# Out:
# 29518.142657342658

# %%
data[data["Temperature"].max() == data["Temperature"]]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 6075  13/09/2016 14:00   1820         33.0    32.0      31.0        19.5
# 6076  13/09/2016 15:00   1873         33.0    32.0      32.0        18.5
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# 6075             1           0           0       2
# 6076             1           0           0       2

# %%
Summer = Season_b.get_group(1)

# %%
Summer
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 3624  01/06/2016 00:00    174         13.0    13.0      88.0        17.0
# 3625  01/06/2016 01:00    115         13.0    13.0      88.0        14.0
# 3626  01/06/2016 02:00     71         13.0    13.0      88.0        15.0
# 3627  01/06/2016 03:00     76         13.0    13.0      88.0        10.0
# 3628  01/06/2016 04:00     84         13.0    13.0      88.0        12.0
# ...                ...    ...          ...     ...       ...         ...
# 5805  31/08/2016 19:00   2750         22.0    22.0      65.0        21.5
# 5806  31/08/2016 20:00   1515         21.0    21.0      69.0        23.0
# 5807  31/08/2016 21:00   1134         20.0    20.0      71.0        19.0
# 5808  31/08/2016 22:00    853         19.0    19.0      64.0        19.5
# 5809  31/08/2016 23:00    511         18.0    18.0      68.0        18.5
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# ...

# %%
Summer[Summer["Temperature"].max() == Summer["Temperature"]]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 5634  24/08/2016 16:00   2727         32.5    32.5      37.0         5.0
# 5635  24/08/2016 17:00   4984         32.5    32.5      37.0        10.5
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# 5634             1           0           0       1
# 5635             1           0           0       1

# %%
data[data['Temperature'].min()==data['Temperature']]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 433   19/01/2016 01:00     36         -1.0    -1.0      86.0         4.0
# 434   19/01/2016 02:00     17         -1.0    -2.5      80.0         3.5
# 435   19/01/2016 03:00     21         -1.0    -1.0      86.0         2.0
# 436   19/01/2016 04:00     25         -1.0    -1.0      83.0         0.0
# 459   20/01/2016 03:00     29         -1.0    -4.0      77.5         7.0
# 460   20/01/2016 04:00     34         -1.0    -3.5      75.0         6.5
# 461   20/01/2016 05:00     71         -1.0    -1.0      75.0         4.0
# 462   20/01/2016 06:00    544         -1.0    -3.5      77.5         7.5
# 463   20/01/2016 07:00   1763         -1.0    -4.0      80.0         8.0
# 482   21/01/2016 02:00     59         -1.0    -3.5      93.0         6.5
# 483   21/01/2016 03:00     32         -1.0    -2.5      93.0         3.5
# 485   21/01/2016 05:00     84         -1.0    -5.0      93.0        11.0
# ...

# %%
data[data['Wind Speed'].max()==data['Wind Speed']]
# Out:
#            Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 920  08/02/2016 15:00    556          9.0     4.0      71.0        56.0
#
#      Weather Code  Is Hoilday  Is Weekend  Season
# 920             7           0           0       3

# %%
Winter = Season_b.get_group(3)

# %%
Winter
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 0     01/01/2016 00:00    786          6.0     3.5      81.0        13.0
# 1     01/01/2016 01:00    660          5.5     3.0      84.0        11.0
# 2     01/01/2016 02:00    387          5.0     2.5      84.0        10.0
# 3     01/01/2016 03:00    294          5.0     4.5      81.0         5.0
# 4     01/01/2016 04:00    219          5.0     4.0      76.0         5.5
# ...                ...    ...          ...     ...       ...         ...
# 8694  31/12/2016 19:00    493          9.0     6.0      82.0        17.0
# 8695  31/12/2016 20:00    465          8.5     6.5      84.5        13.0
# 8696  31/12/2016 21:00    474          8.0     6.0      87.0        12.0
# 8697  31/12/2016 22:00    587          8.0     6.0      90.0        12.0
# 8698  31/12/2016 23:00    697          8.0     5.0      87.0        18.5
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# ...

# %%
Winter[Winter['Count'].min()==Winter['Count']]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 650   28/01/2016 02:00     12          6.5     3.5      68.5        19.5
# 932   09/02/2016 03:00     12          6.0     2.0      71.0        24.0
# 1100  16/02/2016 03:00     12          0.5    -0.5      90.0         5.0
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# 650              1           0           0       3
# 932              3           0           0       3
# 1100             1           0           0       3

# %%
Autumn=Season_b.get_group(2)

# %%
Autumn
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 5810  01/09/2016 00:00    322         18.0    18.0      68.0        15.0
# 5811  01/09/2016 01:00    186         17.0    17.0      73.0        16.0
# 5812  01/09/2016 02:00     89         16.5    16.5      75.0        16.0
# 5813  01/09/2016 03:00     56         16.0    16.0      74.5        11.0
# 5814  01/09/2016 04:00     64         16.0    16.0      77.0        12.0
# ...                ...    ...          ...     ...       ...         ...
# 7950  30/11/2016 19:00   1560          4.5     1.5      63.0        13.0
# 7951  30/11/2016 20:00    969          4.0     1.0      63.0        13.0
# 7952  30/11/2016 21:00    657          4.0     1.0      63.0        13.0
# 7953  30/11/2016 22:00    597          3.0    -0.5      60.0        14.0
# 7954  30/11/2016 23:00    322          3.0    -1.0      62.5        16.0
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# ...

# %%
Autumn[Autumn['Count'].min()==Autumn['Count']]
# Out:
#             Time Stamp  Count  Temperature  F_temp  Humidity  Wind Speed  \
# 7718  21/11/2016 03:00      9          6.0     3.5      93.0        12.0
#
#       Weather Code  Is Hoilday  Is Weekend  Season
# 7718             7           0           0       2

# %%
Spring=Season_b.get_group(0)

# %%
Spring['Humidity'].mean()
# Out:
# 69.88207116788321

# %%
Figures, Axes = plt.subplots(figsize=(140,60))

c=np.random.randint(1,10,size=len(data))
s=np.random.randint(10,220,size=len(data))

Axes.scatter(data['Count'],data['Temperature'],s=s,c=c)

# %%
Labels={"Spring", "Summer", "Autumn", "Winter"}
Counts=Spring['Count'].sum(), Summer['Count'].sum(), Autumn['Count'].sum(), Winter['Count'].sum()

# %%
Figures_2, Axes_2= plt.subplots(figsize=(14,8))

Axes_2.pie(Counts,labels=Labels,autopct='%1.1f%%',explode=[0.1,0,0.1,0])
Axes_2.legend()
plt.show()
